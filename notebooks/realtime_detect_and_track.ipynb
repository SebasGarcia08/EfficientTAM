# %%
import os
import time
import urllib

import cv2
import numpy as np
import torch
from IPython.display import clear_output, display
from PIL import Image

from efficient_track_anything.build_efficienttam import build_efficienttam_object_tracker

# %%
class Visualizer:
    def __init__(self,
                 video_width,
                 video_height,
                 ):
        
        self.video_width = video_width
        self.video_height = video_height

    def resize_mask(self, mask):
        mask = torch.tensor(mask, device='cpu')
        mask = torch.nn.functional.interpolate(mask,
                                               size=(self.video_height, self.video_width),
                                               mode="bilinear",
                                               align_corners=False,
                                               )
        
        return mask

    def add_frame(self, frame, mask):
        frame = frame.copy()
        frame = cv2.resize(frame, (self.video_width, self.video_height))
        
        mask = self.resize_mask(mask=mask)
        mask = (mask > 0.0).numpy()
        
        for i in range(mask.shape[0]):
            obj_mask = mask[i, 0, :, :]
            frame[obj_mask] = [255, 105, 180]
                
        rgb_frame = Image.fromarray(frame)
        clear_output(wait=True)
        display(rgb_frame)

# %%
# Download Example Video
VIDEO_STREAM = "./videos/TUD-Stadtmitte-raw.webm"
VIDEO_STREAM = "./videos/bedroom.mp4"

url = 'https://motchallenge.net/sequenceVideos/TUD-Stadtmitte-raw.webm'

# Check if the file already exists
if not os.path.exists(VIDEO_STREAM):
    # If the file doesn't exist, download it
    urllib.request.urlretrieve(url, VIDEO_STREAM)
    print(f"Downloading {VIDEO_STREAM}...")
else:
    print(f"File {VIDEO_STREAM} already exists, skipping download.")
# Out:
# File ./videos/bedroom.mp4 already exists, skipping download.

# %%
# Set SAM2 Configuration
NUM_OBJECTS = 1
YOLO_CHECKPOINT_FILEPATH = "yolov8x-seg.pt"
SAM_CHECKPOINT_FILEPATH = "../checkpoints/efficienttam_s_512x512.pt"
SAM_CONFIG_FILEPATH = "configs/efficienttam/samurai/efficienttam_s_512x512.yaml"
OUTPUT_PATH = VIDEO_STREAM + "_segmented.mp4"
DEVICE = 'cuda:0'

# %%
# Open Video Stream
video_stream = cv2.VideoCapture(VIDEO_STREAM)

video_height = int(video_stream.get(cv2.CAP_PROP_FRAME_HEIGHT))
video_width = int(video_stream.get(cv2.CAP_PROP_FRAME_WIDTH))

# For real-time visualization
visualizer = Visualizer(video_width=video_width,
                        video_height=video_height
                        )

# %%
sam = build_efficienttam_object_tracker(
    num_objects=NUM_OBJECTS,
	config_file=SAM_CONFIG_FILEPATH,
	ckpt_path=SAM_CHECKPOINT_FILEPATH,
	device=DEVICE,
	verbose=False
)
# Out:
# Image encoder compilation is enabled. First forward pass will be slow.

# %%
available_slots = np.inf

first_frame = True
frame_count = 0
total_time = 0

with torch.inference_mode(), torch.autocast('cuda:0', dtype=torch.bfloat16):
	while video_stream.isOpened():
		start_time = time.time()

		# Get next frame
		ret, frame = video_stream.read()
		
		# Exit if no frames remaining
		if not ret:
			break

		# Convert frame from BGR to RGB
		img = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
		
		# Simulate detection on first frame
		if first_frame:
			bbox = np.array([
				[[172, 92], [254, 325]], 
				[[334, 76],  [439, 329]]]
			)
			points = np.array([[200, 300], [275, 175]], dtype=np.float32)
			# for labels, `1` means positive click and `0` means negative click
			labels = np.array([1, 0], dtype=np.int32)
			# points = np.array([[200, 300]], dtype=np.float32)
			sam_out = sam.track_new_object(
				img=img,
				points=points, labels=labels,
			)
			
			first_frame = False
			
		else:
			sam_out = sam.track_all_objects(img=img)
			
		frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
		visualizer.add_frame(frame=frame_rgb, mask=sam_out['pred_masks'])
		
		# Calculate processing time and FPS
		frame_count += 1
		end_time = time.time()
		frame_time = end_time - start_time
		total_time += frame_time
		
		avg_fps = frame_count / total_time
		print(f"\rProcessing FPS: {avg_fps:.2f}", end="")

video_stream.release()
print(f"\nAverage FPS: {avg_fps:.2f}")
# Out:
# <PIL.Image.Image image mode=RGB size=960x540>
# Processing FPS: 6.63
# Average FPS: 6.63
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
